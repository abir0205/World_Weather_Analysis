# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key
import requests
from datetime import datetime
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
import requests
# Import the API key.
from config import g_key

# %%
# 1. Create a new set of 2,000 random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# 4. Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=96c59c82b0c62cd93888a34be01334d3

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 15 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 16 | ushuaia
# Processing Record 17 of Set 16 | albany
# Processing Record 18 of Set 16 | tarabuco
# Processing Record 19 of Set 16 | shchelyayur
# City not found. Skipping...
# Processing Record 20 of Set 16 | mataura
# Processing Record 21 of Set 16 | bredasdorp
# Processing Record 22 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 16 | kango
# Processing Record 24 of Set 16 | rikitea
# Processing Record 25 of Set 16 | souillac
# Processing Record 26 of Set 16 | necochea
# Processing Record 27 of Set 16 | phalombe
# Processing Record 28 of Set 16 | bluff
# Processing Record 29 of Set 16 | thompson
# Processing Record 30 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 16 | nelson bay
# Processing Record 32 of Set 16 | vila velha
# Processing Record 33 of Set 16 | bengkulu
# Processing Record 34 of Set 16 | seddon
# Processing Record 35 of Set 16 | bezenchuk
# Processing Record 36 of Set 16 | kahului
# Processing Record 37 of Set 16 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 16 | butaritari
# Processing Record 39 of Set 16 | avarua
# Processing Record 40 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 16 | pochutla
# Processing Record 42 of Set 16 | kruisfontein
# Processing Record 43 of Set 16 | yellowknife
# Processing Record 44 of Set 16 | ponta do sol
# Processing Record 45 of Set 16 | atikokan
# Processing Record 46 of Set 16 | bay roberts
# Processing Record 47 of Set 16 | qaanaaq
# Processing Record 48 of Set 16 | oriximina
# Processing Record 49 of Set 16 | verkhoyansk
# Processing Record 50 of Set 16 | souto
# Processing Record 51 of Set 16 | cap malheureux
# Processing Record 52 of Set 16 | ternuvate
# Processing Record 53 of Set 16 | tautira
# Processing Record 54 of Set 16 | husavik
# Processing Record 55 of Set 16 | jamestown
# Processing Record 56 of Set 16 | kwakoa
# Processing Record 57 of Set 16 | cochrane
# Processing Record 58 of Set 16 | aykhal
# Processing Record 59 of Set 16 | san patricio
# Processing Record 60 of Set 16 | jalu
# Processing Record 61 of Set 16 | salta
# Processing Record 62 of Set 16 | airai
# Processing Record 63 of Set 16 | port elizabeth
# Processing Record 64 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 17 | cape town
# Processing Record 2 of Set 17 | flinders
# Processing Record 3 of Set 17 | chokurdakh
# Processing Record 4 of Set 17 | sahrak
# City not found. Skipping...
# Processing Record 5 of Set 17 | carnarvon
# Processing Record 6 of Set 17 | barrow
# Processing Record 7 of Set 17 | weiser
# Processing Record 8 of Set 17 | hobart
# Processing Record 9 of Set 17 | punta arenas
# Processing Record 10 of Set 17 | torbay
# Processing Record 11 of Set 17 | ughelli
# Processing Record 12 of Set 17 | ijaki
# City not found. Skipping...
# Processing Record 13 of Set 17 | new norfolk
# Processing Record 14 of Set 17 | port lincoln
# Processing Record 15 of Set 17 | marsh harbour
# Processing Record 16 of Set 17 | vaini
# Processing Record 17 of Set 17 | kalaleh
# Processing Record 18 of Set 17 | pangody
# Processing Record 19 of Set 17 | kaitangata
# Processing Record 20 of Set 17 | maputo
# Processing Record 21 of Set 17 | tasiilaq
# Processing Record 22 of Set 17 | berezovyy
# Processing Record 23 of Set 17 | juneau
# Processing Record 24 of Set 17 | upernavik
# Processing Record 25 of Set 17 | longyearbyen
# Processing Record 26 of Set 17 | neepawa
# Processing Record 27 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 17 | hofn
# Processing Record 29 of Set 17 | lokosovo
# Processing Record 30 of Set 17 | soma
# Processing Record 31 of Set 17 | ugarcin
# City not found. Skipping...
# Processing Record 32 of Set 17 | cherskiy
# Processing Record 33 of Set 17 | hermanus
# Processing Record 34 of Set 17 | port hedland
# Processing Record 35 of Set 17 | abu dhabi
# Processing Record 36 of Set 17 | yeppoon
# Processing Record 37 of Set 17 | gulmarg
# Processing Record 38 of Set 17 | waingapu
# Processing Record 39 of Set 17 | ribeira grande
# Processing Record 40 of Set 17 | sorland
# Processing Record 41 of Set 17 | nemuro
# Processing Record 42 of Set 17 | busselton
# Processing Record 43 of Set 17 | hilo
# Processing Record 44 of Set 17 | saint-pierre
# Processing Record 45 of Set 17 | burica
# City not found. Skipping...
# Processing Record 46 of Set 17 | la colorada
# Processing Record 47 of Set 17 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 17 | noumea
# Processing Record 49 of Set 17 | vertientes
# Processing Record 50 of Set 17 | buin
# Processing Record 1 of Set 18 | katobu
# Processing Record 2 of Set 18 | khatanga
# Processing Record 3 of Set 18 | arlit
# Processing Record 4 of Set 18 | murray bridge
# Processing Record 5 of Set 18 | ninohe
# Processing Record 6 of Set 18 | kapaa
# Processing Record 7 of Set 18 | saldanha
# Processing Record 8 of Set 18 | paka
# Processing Record 9 of Set 18 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 18 | nicoya
# Processing Record 11 of Set 18 | kununurra
# Processing Record 12 of Set 18 | finschhafen
# Processing Record 13 of Set 18 | sobolevo
# Processing Record 14 of Set 18 | arraial do cabo
# Processing Record 15 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 18 | terrace
# Processing Record 17 of Set 18 | mahebourg
# Processing Record 18 of Set 18 | oranjestad
# Processing Record 19 of Set 18 | okato
# Processing Record 20 of Set 18 | san jeronimo
# Processing Record 21 of Set 18 | anadyr
# Processing Record 22 of Set 18 | kalamb
# Processing Record 23 of Set 18 | mentok
# City not found. Skipping...
# Processing Record 24 of Set 18 | flin flon
# Processing Record 25 of Set 18 | mar del plata
# Processing Record 26 of Set 18 | abu samrah
# Processing Record 27 of Set 18 | bethel
# Processing Record 28 of Set 18 | georgetown
# Processing Record 29 of Set 18 | saint george
# Processing Record 30 of Set 18 | oxford
# Processing Record 31 of Set 18 | nikolskoye
# Processing Record 32 of Set 18 | mundo nuevo
# Processing Record 33 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 18 | tiksi
# Processing Record 35 of Set 18 | richards bay
# Processing Record 36 of Set 18 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 18 | hithadhoo
# Processing Record 38 of Set 18 | abu kamal
# Processing Record 39 of Set 18 | mirebalais
# Processing Record 40 of Set 18 | faanui
# Processing Record 41 of Set 18 | mayo
# Processing Record 42 of Set 18 | maghama
# City not found. Skipping...
# Processing Record 43 of Set 18 | cabo san lucas
# Processing Record 44 of Set 18 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 18 | shadegan
# Processing Record 46 of Set 18 | klaksvik
# Processing Record 47 of Set 18 | clyde river
# Processing Record 48 of Set 18 | samarai
# Processing Record 49 of Set 18 | ornes
# Processing Record 50 of Set 18 | sao felix do xingu
# Processing Record 1 of Set 19 | marienburg
# Processing Record 2 of Set 19 | aleksinac
# Processing Record 3 of Set 19 | touros
# Processing Record 4 of Set 19 | tukrah
# Processing Record 5 of Set 19 | luderitz
# Processing Record 6 of Set 19 | vardo
# Processing Record 7 of Set 19 | codrington
# Processing Record 8 of Set 19 | kavieng
# Processing Record 9 of Set 19 | asau
# Processing Record 10 of Set 19 | talnakh
# Processing Record 11 of Set 19 | graneros
# Processing Record 12 of Set 19 | inhambane
# Processing Record 13 of Set 19 | mount gambier
# Processing Record 14 of Set 19 | roald
# Processing Record 15 of Set 19 | mogadishu
# Processing Record 16 of Set 19 | east london
# Processing Record 17 of Set 19 | lavrentiya
# Processing Record 18 of Set 19 | labuhan
# Processing Record 19 of Set 19 | sioux lookout
# Processing Record 20 of Set 19 | khasan
# Processing Record 21 of Set 19 | acarau
# Processing Record 22 of Set 19 | saskylakh
# Processing Record 23 of Set 19 | hobyo
# Processing Record 24 of Set 19 | naze
# Processing Record 25 of Set 19 | wad rawah
# Processing Record 26 of Set 19 | bodden town
# Processing Record 27 of Set 19 | kapoeta
# Processing Record 28 of Set 19 | nizhniy baskunchak
# Processing Record 29 of Set 19 | tuktoyaktuk
# Processing Record 30 of Set 19 | coahuayana
# Processing Record 31 of Set 19 | norman wells
# Processing Record 32 of Set 19 | victoria
# Processing Record 33 of Set 19 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 19 | gouyave
# Processing Record 35 of Set 19 | agva
# City not found. Skipping...
# Processing Record 36 of Set 19 | poronaysk
# Processing Record 37 of Set 19 | mehamn
# Processing Record 38 of Set 19 | leningradskiy
# Processing Record 39 of Set 19 | atuona
# Processing Record 40 of Set 19 | saint-louis
# Processing Record 41 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 19 | castro
# Processing Record 43 of Set 19 | esperance
# Processing Record 44 of Set 19 | ucluelet
# Processing Record 45 of Set 19 | ancud
# Processing Record 46 of Set 19 | wanaka
# Processing Record 47 of Set 19 | portobelo
# Processing Record 48 of Set 19 | ilulissat
# Processing Record 49 of Set 19 | price
# Processing Record 50 of Set 19 | guantanamo
# Processing Record 1 of Set 20 | gamboma
# Processing Record 2 of Set 20 | conde
# Processing Record 3 of Set 20 | balaipungut
# Processing Record 4 of Set 20 | sitka
# Processing Record 5 of Set 20 | cabrero
# Processing Record 6 of Set 20 | maningrida
# Processing Record 7 of Set 20 | lebu
# Processing Record 8 of Set 20 | huazolotitlan
# City not found. Skipping...
# Processing Record 9 of Set 20 | villafranca di verona
# Processing Record 10 of Set 20 | lake havasu city
# Processing Record 11 of Set 20 | kikwit
# Processing Record 12 of Set 20 | san isidro
# Processing Record 13 of Set 20 | saint-philippe
# Processing Record 14 of Set 20 | huaibei
# Processing Record 15 of Set 20 | puerto ayora
# Processing Record 16 of Set 20 | nouakchott
# Processing Record 17 of Set 20 | chuy
# Processing Record 18 of Set 20 | kloulklubed
# Processing Record 19 of Set 20 | skibbereen
# Processing Record 20 of Set 20 | awjilah
# Processing Record 21 of Set 20 | sayyan
# Processing Record 22 of Set 20 | itapetinga
# Processing Record 23 of Set 20 | los llanos de aridane
# Processing Record 24 of Set 20 | milkovo
# Processing Record 25 of Set 20 | caxito
# Processing Record 26 of Set 20 | iqaluit
# Processing Record 27 of Set 20 | winder
# Processing Record 28 of Set 20 | teguise
# Processing Record 29 of Set 20 | faya
# Processing Record 30 of Set 20 | meulaboh
# Processing Record 31 of Set 20 | dubbo
# Processing Record 32 of Set 20 | cayenne
# Processing Record 33 of Set 20 | ulagan
# Processing Record 34 of Set 20 | katsuura
# Processing Record 35 of Set 20 | broken hill
# Processing Record 36 of Set 20 | greensboro
# Processing Record 37 of Set 20 | abnub
# Processing Record 38 of Set 20 | mehriz
# Processing Record 39 of Set 20 | ahtopol
# Processing Record 40 of Set 20 | sembakung
# Processing Record 41 of Set 20 | kigoma
# Processing Record 42 of Set 20 | keuruu
# Processing Record 43 of Set 20 | ulaanbaatar
# Processing Record 44 of Set 20 | kuytun
# Processing Record 45 of Set 20 | ostrovnoy
# Processing Record 46 of Set 20 | cap-aux-meules
# Processing Record 47 of Set 20 | te anau
# Processing Record 48 of Set 20 | kodiak
# Processing Record 49 of Set 20 | beian
# Processing Record 50 of Set 20 | haines junction
# Processing Record 1 of Set 21 | trofors
# Processing Record 2 of Set 21 | dali
# Processing Record 3 of Set 21 | portgordon
# Processing Record 4 of Set 21 | dikson
# Processing Record 5 of Set 21 | vila do maio
# Processing Record 6 of Set 21 | north bend
# Processing Record 7 of Set 21 | yumen
# Processing Record 8 of Set 21 | porto novo
# Processing Record 9 of Set 21 | dehloran
# Processing Record 10 of Set 21 | witrivier
# City not found. Skipping...
# Processing Record 11 of Set 21 | pevek
# Processing Record 12 of Set 21 | qeshm
# Processing Record 13 of Set 21 | cidreira
# Processing Record 14 of Set 21 | tual
# Processing Record 15 of Set 21 | pangnirtung
# Processing Record 16 of Set 21 | inyonga
# Processing Record 17 of Set 21 | vrede
# Processing Record 18 of Set 21 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 21 | alamos
# Processing Record 20 of Set 21 | saint anthony
# Processing Record 21 of Set 21 | kedrovyy
# Processing Record 22 of Set 21 | san andres
# Processing Record 23 of Set 21 | troitskoye
# Processing Record 24 of Set 21 | kirakira
# Processing Record 25 of Set 21 | narsaq
# Processing Record 26 of Set 21 | tessalit
# Processing Record 27 of Set 21 | almunecar
# Processing Record 28 of Set 21 | gravelbourg
# Processing Record 29 of Set 21 | cuenca
# Processing Record 30 of Set 21 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 21 | lasa
# Processing Record 32 of Set 21 | honningsvag
# Processing Record 33 of Set 21 | constitucion
# Processing Record 34 of Set 21 | zhigansk
# Processing Record 35 of Set 21 | deputatskiy
# Processing Record 36 of Set 21 | san francisco
# Processing Record 37 of Set 21 | lumeje
# Processing Record 38 of Set 21 | tateyama
# Processing Record 39 of Set 21 | parainen
# Processing Record 40 of Set 21 | chapais
# Processing Record 41 of Set 21 | seaca de camp
# Processing Record 42 of Set 21 | riihimaki
# Processing Record 43 of Set 21 | bambous virieux
# Processing Record 44 of Set 21 | mareeba
# Processing Record 45 of Set 21 | fuerte olimpo
# Processing Record 46 of Set 21 | puyang
# Processing Record 47 of Set 21 | nador
# Processing Record 48 of Set 21 | cockburn town
# Processing Record 49 of Set 21 | san jose
# Processing Record 50 of Set 21 | graaff-reinet
# Processing Record 1 of Set 22 | tucano
# Processing Record 2 of Set 22 | corsicana
# Processing Record 3 of Set 22 | pontianak
# Processing Record 4 of Set 22 | kurandvad
# Processing Record 5 of Set 22 | riyadh
# Processing Record 6 of Set 22 | kiama
# Processing Record 7 of Set 22 | bonthe
# Processing Record 8 of Set 22 | agua fria
# Processing Record 9 of Set 22 | ornskoldsvik
# Processing Record 10 of Set 22 | namanga
# Processing Record 11 of Set 22 | sinjar
# Processing Record 12 of Set 22 | amapa
# Processing Record 13 of Set 22 | angola
# Processing Record 14 of Set 22 | eureka
# Processing Record 15 of Set 22 | portland
# Processing Record 16 of Set 22 | jimma
# Processing Record 17 of Set 22 | hambantota
# Processing Record 18 of Set 22 | karratha
# Processing Record 19 of Set 22 | maneadero
# Processing Record 20 of Set 22 | batagay-alyta
# Processing Record 21 of Set 22 | camacha
# Processing Record 22 of Set 22 | shingu
# Processing Record 23 of Set 22 | tura
# Processing Record 24 of Set 22 | rio claro
# Processing Record 25 of Set 22 | lyngseidet
# Processing Record 26 of Set 22 | santa maria
# Processing Record 27 of Set 22 | nianzishan
# Processing Record 28 of Set 22 | baihar
# Processing Record 29 of Set 22 | ahipara
# Processing Record 30 of Set 22 | nouadhibou
# Processing Record 31 of Set 22 | peniche
# Processing Record 32 of Set 22 | ugoofaaru
# Processing Record 33 of Set 22 | muros
# Processing Record 34 of Set 22 | locri
# Processing Record 35 of Set 22 | whitehorse
# Processing Record 36 of Set 22 | rabo de peixe
# Processing Record 37 of Set 22 | banda aceh
# Processing Record 38 of Set 22 | tommot
# Processing Record 39 of Set 22 | tazovskiy
# Processing Record 40 of Set 22 | seoul
# Processing Record 41 of Set 22 | hamilton
# Processing Record 42 of Set 22 | olafsvik
# Processing Record 43 of Set 22 | westport
# Processing Record 44 of Set 22 | tasbuget
# City not found. Skipping...
# Processing Record 45 of Set 22 | qandala
# Processing Record 46 of Set 22 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 22 | rosa zarate
# Processing Record 48 of Set 22 | severo-kurilsk
# Processing Record 49 of Set 22 | biak
# Processing Record 50 of Set 22 | chicama
# Processing Record 1 of Set 23 | ust-nera
# Processing Record 2 of Set 23 | omboue
# Processing Record 3 of Set 23 | maceio
# Processing Record 4 of Set 23 | lewiston
# Processing Record 5 of Set 23 | odweyne
# Processing Record 6 of Set 23 | vila
# Processing Record 7 of Set 23 | kouroussa
# Processing Record 8 of Set 23 | sandwick
# Processing Record 9 of Set 23 | beringovskiy
# Processing Record 10 of Set 23 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 23 | mopipi
# Processing Record 12 of Set 23 | serrinha
# Processing Record 13 of Set 23 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 23 | isangel
# Processing Record 15 of Set 23 | poum
# Processing Record 16 of Set 23 | atherton
# Processing Record 17 of Set 23 | provideniya
# Processing Record 18 of Set 23 | guangshui
# Processing Record 19 of Set 23 | vanimo
# Processing Record 20 of Set 23 | muzhi
# Processing Record 21 of Set 23 | hualmay
# Processing Record 22 of Set 23 | majene
# Processing Record 23 of Set 23 | san pedro
# Processing Record 24 of Set 23 | ambon
# Processing Record 25 of Set 23 | mindelo
# Processing Record 26 of Set 23 | kiunga
# Processing Record 27 of Set 23 | bac lieu
# Processing Record 28 of Set 23 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 23 | altamont
# Processing Record 30 of Set 23 | nakhon ratchasima
# Processing Record 31 of Set 23 | port alfred
# Processing Record 32 of Set 23 | buala
# Processing Record 33 of Set 23 | yeehaw junction
# City not found. Skipping...
# Processing Record 34 of Set 23 | dingle
# Processing Record 35 of Set 23 | dudinka
# Processing Record 36 of Set 23 | hasaki
# Processing Record 37 of Set 23 | akdepe
# Processing Record 38 of Set 23 | basco
# Processing Record 39 of Set 23 | paita
# Processing Record 40 of Set 23 | zhongxing
# Processing Record 41 of Set 23 | nacogdoches
# Processing Record 42 of Set 23 | luanda
# Processing Record 43 of Set 23 | san policarpo
# Processing Record 44 of Set 23 | ponta delgada
# Processing Record 45 of Set 23 | ulladulla
# Processing Record 46 of Set 23 | aberdeen
# Processing Record 47 of Set 23 | milingimbi
# City not found. Skipping...
# Processing Record 48 of Set 23 | rauma
# Processing Record 49 of Set 23 | evensk
# Processing Record 50 of Set 23 | sept-iles
# Processing Record 1 of Set 24 | kamaishi
# Processing Record 2 of Set 24 | oum hadjer
# Processing Record 3 of Set 24 | tuatapere
# Processing Record 4 of Set 24 | susehri
# Processing Record 5 of Set 24 | roblin
# Processing Record 6 of Set 24 | pecos
# Processing Record 7 of Set 24 | vestmanna
# Processing Record 8 of Set 24 | trowbridge
# Processing Record 9 of Set 24 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 24 | verkhnya syrovatka
# Processing Record 11 of Set 24 | grindavik
# Processing Record 12 of Set 24 | sao filipe
# Processing Record 13 of Set 24 | tuensang
# Processing Record 14 of Set 24 | kropotkin
# Processing Record 15 of Set 24 | constantine
# Processing Record 16 of Set 24 | dicabisagan
# Processing Record 17 of Set 24 | itanagar
# Processing Record 18 of Set 24 | kavaratti
# Processing Record 19 of Set 24 | sawakin
# Processing Record 20 of Set 24 | kovylkino
# Processing Record 21 of Set 24 | caravelas
# Processing Record 22 of Set 24 | jinja
# Processing Record 23 of Set 24 | moron
# Processing Record 24 of Set 24 | valparaiso
# Processing Record 25 of Set 24 | pisco
# Processing Record 26 of Set 24 | oktyabrskoye
# Processing Record 27 of Set 24 | dahod
# Processing Record 28 of Set 24 | hun
# Processing Record 29 of Set 24 | najran
# Processing Record 30 of Set 24 | kirensk
# Processing Record 31 of Set 24 | puro
# Processing Record 32 of Set 24 | maldonado
# Processing Record 33 of Set 24 | saposoa
# Processing Record 34 of Set 24 | davila
# Processing Record 35 of Set 24 | radyvyliv
# Processing Record 36 of Set 24 | dwarka
# Processing Record 37 of Set 24 | rawlins
# Processing Record 38 of Set 24 | bathsheba
# Processing Record 39 of Set 24 | geraldton
# Processing Record 40 of Set 24 | batagay
# Processing Record 41 of Set 24 | aktash
# Processing Record 42 of Set 24 | tokur
# Processing Record 43 of Set 24 | cervo
# Processing Record 44 of Set 24 | kuusamo
# Processing Record 45 of Set 24 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 24 | dayong
# Processing Record 47 of Set 24 | ciudad ojeda
# Processing Record 48 of Set 24 | srivardhan
# Processing Record 49 of Set 24 | quarai
# Processing Record 50 of Set 24 | saryshagan
# City not found. Skipping...
# Processing Record 1 of Set 25 | say
# Processing Record 2 of Set 25 | viedma
# Processing Record 3 of Set 25 | ilheus
# Processing Record 4 of Set 25 | catole do rocha
# Processing Record 5 of Set 25 | kaohsiung
# Processing Record 6 of Set 25 | quelimane
# Processing Record 7 of Set 25 | quatre cocos
# Processing Record 8 of Set 25 | port blair
# Processing Record 9 of Set 25 | umea
# Processing Record 10 of Set 25 | college
# Processing Record 11 of Set 25 | linhares
# Processing Record 12 of Set 25 | kapit
# Processing Record 13 of Set 25 | fukue
# Processing Record 14 of Set 25 | dalvik
# Processing Record 15 of Set 25 | blagoyevo
# Processing Record 16 of Set 25 | serowe
# Processing Record 17 of Set 25 | komsomolskiy
# Processing Record 18 of Set 25 | nome
# Processing Record 19 of Set 25 | surt
# Processing Record 20 of Set 25 | bethanien
# Processing Record 21 of Set 25 | makokou
# Processing Record 22 of Set 25 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 25 | weihe
# Processing Record 24 of Set 25 | bantry
# Processing Record 25 of Set 25 | zirandaro
# Processing Record 26 of Set 25 | morgan city
# Processing Record 27 of Set 25 | lorengau
# Processing Record 28 of Set 25 | bone
# Processing Record 29 of Set 25 | santa ana
# Processing Record 30 of Set 25 | lagoa
# Processing Record 31 of Set 25 | srednekolymsk
# Processing Record 32 of Set 25 | kamina
# Processing Record 33 of Set 25 | hurricane
# Processing Record 34 of Set 25 | fortuna
# Processing Record 35 of Set 25 | roebourne
# Processing Record 36 of Set 25 | nuevo casas grandes
# Processing Record 37 of Set 25 | prince george
# Processing Record 38 of Set 25 | broome
# Processing Record 39 of Set 25 | blythe
# Processing Record 40 of Set 25 | banyo
# Processing Record 41 of Set 25 | mahaicony
# City not found. Skipping...
# Processing Record 42 of Set 25 | nanortalik
# Processing Record 43 of Set 25 | karaton
# Processing Record 44 of Set 25 | springville
# Processing Record 45 of Set 25 | ambulu
# Processing Record 46 of Set 25 | loa janan
# Processing Record 47 of Set 25 | launceston
# Processing Record 48 of Set 25 | helong
# Processing Record 49 of Set 25 | fort nelson
# Processing Record 50 of Set 25 | kangaba
# Processing Record 1 of Set 26 | praia da vitoria
# Processing Record 2 of Set 26 | morros
# Processing Record 3 of Set 26 | tutoia
# Processing Record 4 of Set 26 | hami
# Processing Record 5 of Set 26 | naliya
# Processing Record 6 of Set 26 | zamardi
# Processing Record 7 of Set 26 | bonavista
# Processing Record 8 of Set 26 | ashqelon
# Processing Record 9 of Set 26 | lahij
# Processing Record 10 of Set 26 | sakakah
# Processing Record 11 of Set 26 | inuvik
# Processing Record 12 of Set 26 | ixtapa
# Processing Record 13 of Set 26 | fort-shevchenko
# Processing Record 14 of Set 26 | goderich
# Processing Record 15 of Set 26 | grand gaube
# Processing Record 16 of Set 26 | kishi
# Processing Record 17 of Set 26 | igrim
# Processing Record 18 of Set 26 | alugan
# Processing Record 19 of Set 26 | ituni
# City not found. Skipping...
# Processing Record 20 of Set 26 | hirara
# Processing Record 21 of Set 26 | mount isa
# Processing Record 22 of Set 26 | cartagena del chaira
# Processing Record 23 of Set 26 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 26 | mahon
# Processing Record 25 of Set 26 | coihaique
# Processing Record 26 of Set 26 | vestmannaeyjar
# Processing Record 27 of Set 26 | hwange
# Processing Record 28 of Set 26 | moosomin
# Processing Record 29 of Set 26 | general pico
# Processing Record 30 of Set 26 | zlobin
# Processing Record 31 of Set 26 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 26 | cabedelo
# Processing Record 33 of Set 26 | byron bay
# Processing Record 34 of Set 26 | nanfeng
# Processing Record 35 of Set 26 | piet retief
# Processing Record 36 of Set 26 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 26 | opuwo
# Processing Record 38 of Set 26 | tarakan
# Processing Record 39 of Set 26 | sola
# Processing Record 40 of Set 26 | zhezkazgan
# Processing Record 41 of Set 26 | atamanovka
# Processing Record 42 of Set 26 | gizo
# Processing Record 43 of Set 26 | niamey
# Processing Record 44 of Set 26 | guerrero negro
# Processing Record 45 of Set 26 | luganville
# Processing Record 46 of Set 26 | svetlyy
# Processing Record 47 of Set 26 | toropets
# Processing Record 48 of Set 26 | kindu
# Processing Record 49 of Set 26 | assai
# Processing Record 50 of Set 26 | kropachevo
# Processing Record 1 of Set 27 | yurla
# Processing Record 2 of Set 27 | antanifotsy
# Processing Record 3 of Set 27 | kursk
# Processing Record 4 of Set 27 | atar
# Processing Record 5 of Set 27 | bonito
# Processing Record 6 of Set 27 | havre-saint-pierre
# Processing Record 7 of Set 27 | paliambela
# Processing Record 8 of Set 27 | tezu
# Processing Record 9 of Set 27 | plock
# Processing Record 10 of Set 27 | nara
# Processing Record 11 of Set 27 | bouna
# Processing Record 12 of Set 27 | kushima
# Processing Record 13 of Set 27 | palora
# Processing Record 14 of Set 27 | kortkeros
# Processing Record 15 of Set 27 | la plata
# Processing Record 16 of Set 27 | chitipa
# Processing Record 17 of Set 27 | paredon
# Processing Record 18 of Set 27 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 27 | athabasca
# Processing Record 20 of Set 27 | hellvik
# Processing Record 21 of Set 27 | ihosy
# Processing Record 22 of Set 27 | coquimbo
# Processing Record 23 of Set 27 | port said
# Processing Record 24 of Set 27 | dunedin
# Processing Record 25 of Set 27 | ilhabela
# Processing Record 26 of Set 27 | punta de bombon
# Processing Record 27 of Set 27 | independencia
# Processing Record 28 of Set 27 | salalah
# Processing Record 29 of Set 27 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 27 | tiznit
# Processing Record 31 of Set 27 | altus
# Processing Record 32 of Set 27 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 27 | mahanoro
# Processing Record 34 of Set 27 | shakawe
# Processing Record 35 of Set 27 | vaitape
# Processing Record 36 of Set 27 | karasjok
# Processing Record 37 of Set 27 | diamantino
# Processing Record 38 of Set 27 | gardan diwal
# City not found. Skipping...
# Processing Record 39 of Set 27 | lompoc
# Processing Record 40 of Set 27 | mocuba
# Processing Record 41 of Set 27 | chifeng
# Processing Record 42 of Set 27 | toungoo
# City not found. Skipping...
# Processing Record 43 of Set 27 | harlingen
# Processing Record 44 of Set 27 | talara
# Processing Record 45 of Set 27 | cedartown
# Processing Record 46 of Set 27 | benemerito de las americas
# Processing Record 47 of Set 27 | laguna de perlas
# Processing Record 48 of Set 27 | kangaatsiaq
# Processing Record 49 of Set 27 | namangan
# Processing Record 50 of Set 27 | dire
# Processing Record 1 of Set 28 | bonfim
# Processing Record 2 of Set 28 | tumsar
# Processing Record 3 of Set 28 | iki-burul
# Processing Record 4 of Set 28 | pishin
# Processing Record 5 of Set 28 | port-gentil
# Processing Record 6 of Set 28 | clearwater
# Processing Record 7 of Set 28 | ust-shonosha
# Processing Record 8 of Set 28 | umm lajj
# Processing Record 9 of Set 28 | ordynskoye
# Processing Record 10 of Set 28 | bahia blanca
# Processing Record 11 of Set 28 | odienne
# Processing Record 12 of Set 28 | atambua
# Processing Record 13 of Set 28 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 28 | aklavik
# Processing Record 15 of Set 28 | bundaberg
# Processing Record 16 of Set 28 | marsabit
# Processing Record 17 of Set 28 | moose factory
# Processing Record 18 of Set 28 | kawalu
# Processing Record 19 of Set 28 | goya
# Processing Record 20 of Set 28 | jumla
# Processing Record 21 of Set 28 | mamakan
# Processing Record 22 of Set 28 | bima
# Processing Record 23 of Set 28 | turriff
# Processing Record 24 of Set 28 | burkhala
# City not found. Skipping...
# Processing Record 25 of Set 28 | ji-parana
# City not found. Skipping...
# Processing Record 26 of Set 28 | axim
# Processing Record 27 of Set 28 | kidal
# Processing Record 28 of Set 28 | chodziez
# Processing Record 29 of Set 28 | kyren
# Processing Record 30 of Set 28 | nagua
# Processing Record 31 of Set 28 | turbat
# Processing Record 32 of Set 28 | polis
# Processing Record 33 of Set 28 | sinop
# Processing Record 34 of Set 28 | calvinia
# Processing Record 35 of Set 28 | fandriana
# Processing Record 36 of Set 28 | laguna
# Processing Record 37 of Set 28 | koumac
# Processing Record 38 of Set 28 | marion
# Processing Record 39 of Set 28 | gushikawa
# Processing Record 40 of Set 28 | bend
# Processing Record 41 of Set 28 | uzunkopru
# City not found. Skipping...
# Processing Record 42 of Set 28 | palmer
# Processing Record 43 of Set 28 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 28 | takapau
# Processing Record 45 of Set 28 | gumdag
# Processing Record 46 of Set 28 | lata
# Processing Record 47 of Set 28 | northam
# Processing Record 48 of Set 28 | matay
# Processing Record 49 of Set 28 | panalingaan
# Processing Record 50 of Set 28 | mao
# Processing Record 1 of Set 29 | lichinga
# Processing Record 2 of Set 29 | margate
# Processing Record 3 of Set 29 | olinda
# Processing Record 4 of Set 29 | padang
# Processing Record 5 of Set 29 | lamu
# Processing Record 6 of Set 29 | itarema
# Processing Record 7 of Set 29 | ambilobe
# Processing Record 8 of Set 29 | bandarbeyla
# Processing Record 9 of Set 29 | kaeo
# Processing Record 10 of Set 29 | oksfjord
# Processing Record 11 of Set 29 | pustoshka
# Processing Record 12 of Set 29 | bethal
# Processing Record 13 of Set 29 | senekal
# Processing Record 14 of Set 29 | vao
# Processing Record 15 of Set 29 | cedar city
# Processing Record 16 of Set 29 | porto velho
# Processing Record 17 of Set 29 | aurora
# Processing Record 18 of Set 29 | yefimovskiy
# City not found. Skipping...
# Processing Record 19 of Set 29 | antalaha
# Processing Record 20 of Set 29 | rajula
# Processing Record 21 of Set 29 | djibo
# Processing Record 22 of Set 29 | xiutetelco
# City not found. Skipping...
# Processing Record 23 of Set 29 | roura
# Processing Record 24 of Set 29 | dalby
# Processing Record 25 of Set 29 | acapulco
# Processing Record 26 of Set 29 | namtsy
# Processing Record 27 of Set 29 | alta floresta
# Processing Record 28 of Set 29 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 29 | aquidauana
# Processing Record 30 of Set 29 | sardarpur
# Processing Record 31 of Set 29 | liberal
# Processing Record 32 of Set 29 | bosaso
# Processing Record 33 of Set 29 | emerald
# Processing Record 34 of Set 29 | aitape
# Processing Record 35 of Set 29 | vidosi
# Processing Record 36 of Set 29 | preobrazheniye
# Processing Record 37 of Set 29 | texarkana
# Processing Record 38 of Set 29 | namatanai
# Processing Record 39 of Set 29 | vammala
# Processing Record 40 of Set 29 | namibe
# Processing Record 41 of Set 29 | tonekabon
# Processing Record 42 of Set 29 | manacapuru
# Processing Record 43 of Set 29 | wuwei
# Processing Record 44 of Set 29 | hovd
# Processing Record 45 of Set 29 | pokhara
# Processing Record 46 of Set 29 | wakefield
# Processing Record 47 of Set 29 | gorontalo
# Processing Record 48 of Set 29 | batemans bay
# Processing Record 49 of Set 29 | olga
# Processing Record 50 of Set 29 | egvekinot
# Processing Record 1 of Set 30 | kemijarvi
# Processing Record 2 of Set 30 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 30 | chumikan
# Processing Record 4 of Set 30 | sulangan
# Processing Record 5 of Set 30 | taoudenni
# Processing Record 6 of Set 30 | russkaya polyana
# Processing Record 7 of Set 30 | solt
# Processing Record 8 of Set 30 | bor
# Processing Record 9 of Set 30 | plettenberg bay
# Processing Record 10 of Set 30 | wana
# Processing Record 11 of Set 30 | horasan
# Processing Record 12 of Set 30 | bulawayo
# Processing Record 13 of Set 30 | iwaki
# Processing Record 14 of Set 30 | korla
# Processing Record 15 of Set 30 | awbari
# Processing Record 16 of Set 30 | floro
# Processing Record 17 of Set 30 | gualaquiza
# Processing Record 18 of Set 30 | sinnamary
# Processing Record 19 of Set 30 | hackettstown
# Processing Record 20 of Set 30 | tomatlan
# Processing Record 21 of Set 30 | kutum
# Processing Record 22 of Set 30 | semey
# Processing Record 23 of Set 30 | tucupita
# Processing Record 24 of Set 30 | la macarena
# Processing Record 25 of Set 30 | hay river
# Processing Record 26 of Set 30 | guanare
# Processing Record 27 of Set 30 | erenhot
# Processing Record 28 of Set 30 | huron
# Processing Record 29 of Set 30 | damphu
# Processing Record 30 of Set 30 | qasigiannguit
# Processing Record 31 of Set 30 | puerto carreno
# Processing Record 32 of Set 30 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 30 | hazorasp
# Processing Record 34 of Set 30 | gigmoto
# Processing Record 35 of Set 30 | temir
# Processing Record 36 of Set 30 | tosya
# Processing Record 37 of Set 30 | avera
# Processing Record 38 of Set 30 | naron
# Processing Record 39 of Set 30 | san ramon
# Processing Record 40 of Set 30 | binika
# Processing Record 41 of Set 30 | hays
# Processing Record 42 of Set 30 | campbell river
# Processing Record 43 of Set 30 | huanren
# Processing Record 44 of Set 30 | zyryanovskiy
# City not found. Skipping...
# Processing Record 45 of Set 30 | buraydah
# Processing Record 46 of Set 30 | tabuk
# Processing Record 47 of Set 30 | lagunas
# Processing Record 48 of Set 30 | bela
# Processing Record 49 of Set 30 | mugumu
# Processing Record 50 of Set 30 | smirnykh
# Processing Record 1 of Set 31 | fort dodge
# Processing Record 2 of Set 31 | christchurch
# Processing Record 3 of Set 31 | nagato
# Processing Record 4 of Set 31 | east liverpool
# Processing Record 5 of Set 31 | jindrichuv hradec
# Processing Record 6 of Set 31 | svetlogorsk
# Processing Record 7 of Set 31 | ketchikan
# Processing Record 8 of Set 31 | phan thiet
# Processing Record 9 of Set 31 | wembley
# Processing Record 10 of Set 31 | matera
# Processing Record 11 of Set 31 | diffa
# Processing Record 12 of Set 31 | gorkovskoye
# City not found. Skipping...
# Processing Record 13 of Set 31 | al
# City not found. Skipping...
# Processing Record 14 of Set 31 | nao-me-toque
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City  Cloudiness Country                 Date  Humidity      Lat  \
# 0     Ushuaia          75      NE  2021-06-01 02:08:21        93 -54.8000
# 1      Albany          53      NE  2021-06-01 02:08:21        88  42.6001
# 2    Tarabuco         100      NE  2021-06-01 02:08:21        83 -19.1667
# 3     Mataura          62      NE  2021-06-01 02:08:22        72 -46.1927
# 4  Bredasdorp          10      NE  2021-06-01 02:08:22        90 -34.5322
#
#         Lng  Max Temp          Weather  Wind Speed
# 0  -68.3000     29.86    broken clouds        5.75
# 1  -73.9662     54.45    broken clouds        4.94
# 2  -64.9167     45.55  overcast clouds        3.15
# 3  168.8643     49.48    broken clouds        3.31
# 4   20.0403     50.29        clear sky        6.60

# %%
# Create the output file (CSV).
city_data_csv = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(city_data_csv, index_label="City_ID")
